# %%
name=str(input("Enter your name:-->"))
age=int(input("Enter your age:-->"))
add=str(input("Enter your add:-->"))
clg=str(input("Enter your colleage name:-->"))
per=float(input("Enter your per:-->"))
print("\nname:-->",name ,"\nage:-->",age , "\naddress:-->",add, "\ncolleage:-->",clg, "\npercentage:-->",per)
# Out:
# Enter your name:--> Yashraj Sharma
# Enter your age:--> 20
# Enter your add:--> 21, Shiv Residency, Madhuram Circle , Dindoli,Surat
# Enter your colleage name:--> VTP BCA College
# Enter your per:--> 80
# name:--> Yashraj Sharma
# age:--> 20
# address:--> 21, Shiv Residency, Madhuram Circle , Dindoli,Surat
# colleage:--> VTP BCA College
# percentage:--> 80.0

# %%
a = int(input("Enter first value:-->"))
b = int(input("Enter second number:-->"))

divide = a/b
Multiplication = a*b
Addition = a+b
Subtraction = a-b
Modulus = a%b

print("divide:-->",divide)
print("Multiplication:-->",Multiplication)
print("Addition:-->",Addition)
print("Subtraction:-->",Subtraction)
print("Modulus:-->",Modulus)
# Out:
# Enter first value:--> 25
# Enter second number:--> 2
# divide:--> 12.5
# Multiplication:--> 50
# Addition:--> 27
# Subtraction:--> 23
# Modulus:--> 1
